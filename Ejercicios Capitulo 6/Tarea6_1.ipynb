# %% [markdown]
# # Capitulo 6 Ejercicio 1
# Tome una ecuación determinada, por ejemplo una raíz cuadrada o
# cúbica, o un seno, genere un data set con muchos valores. Con base en ese data set y utilizando
# una herramienta de ML, encuentre un modelo para el cálculo de la raíz cuadrada. Úselo con 10
# ejemplos y compare los resultados con los que da la función del lenguaje.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

np.random.seed(0)
X = np.sort(5 * np.random.rand(80, 1), axis=0)
y = np.sqrt(X)

# Crear un modelo de red neuronal simple que es una herramienta de ML
model = keras.Sequential([
    keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

# Entrenar el modelo
model.fit(X, y, epochs=1000, verbose=0)

# Crear un conjunto de datos de prueba con 10 ejemplos
X_test = np.linspace(0, 5, 10).reshape(-1, 1)

# Predecir los valores de la raíz cuadrada utilizando el modelo
y_pred = model.predict(X_test)

# Mostrar los resultados para los 10 ejemplos
for i in range(len(X_test)):
    x_val = X_test[i][0]
    true_val = np.sqrt(x_val)
    pred_val = y_pred[i][0]
    print(f"Entrada: {x_val:.2f}, Valor real: {true_val:.4f}, Valor predicho: {pred_val:.4f}")

# Mostrar los resultados en un gráfico
plt.scatter(X, y, s=20, label="Datos")
plt.plot(X_test, np.sqrt(X_test), color='r', linestyle='--', label="Función Real")
plt.plot(X_test, y_pred, color='g', label="Modelo de ML (Red Neuronal)")
plt.xlabel("X")
plt.ylabel("Raíz Cuadrada")
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 1s 525ms/step
# Entrada: 0.00, Valor real: 0.0000, Valor predicho: 0.3996
# Entrada: 0.56, Valor real: 0.7454, Valor predicho: 0.7256
# Entrada: 1.11, Valor real: 1.0541, Valor predicho: 1.0516
# Entrada: 1.67, Valor real: 1.2910, Valor predicho: 1.3142
# Entrada: 2.22, Valor real: 1.4907, Valor predicho: 1.4761
# Entrada: 2.78, Valor real: 1.6667, Valor predicho: 1.6381
# Entrada: 3.33, Valor real: 1.8257, Valor predicho: 1.8001
# Entrada: 3.89, Valor real: 1.9720, Valor predicho: 1.9621
# Entrada: 4.44, Valor real: 2.1082, Valor predicho: 2.1240
# Entrada: 5.00, Valor real: 2.2361, Valor predicho: 2.2860
